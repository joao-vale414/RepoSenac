# %%
#1. Criar um dicionário:
dados = {}
aluno = {"nome": "Ana", "idade": 16, "nota": 9.0}

# %%
#2. Acessar valores:
print(aluno["nome"]) # Ana

# %%
#3. Adicionar ou modificar valores:
aluno["nota"] = 9.5
aluno["turma"] = "3A"

# %%
#4. Remover itens:
del aluno["idade"]

# %%
#5. Obter apenas chaves, valores ou ambos:
print(aluno.keys())
print(aluno.values())
print(aluno.items())

# %%
#6. Verificar se uma chave existe:
if "nome" in aluno:
 print("Nome encontrado!")

# %%
#7. Tamanho do dicionário:
print(len(aluno))

# %%
#8. Limpar o dicionário:
aluno.clear()

# %%
#9. Copiar um dicionário:
copia = aluno.copy()

# %%
#10. Iterar sobre o dicionário:
for chave, valor in aluno.items():
 print(f"{chave}: {valor}")

# %%
#11. Usar get() para acessar valores com segurança:
print(aluno.get("nome"))
print(aluno.get("endereco"))

# %%
#12. Atualizar um dicionário com outro:
dados_novos = {"nota": 10, "cidade": "Rio"}
aluno.update(dados_novos)

# %%
#13. Substituir valor:
aluno["idade"] = 17

# %%
#14. Apagar chave:
del aluno["idade"]

# %%
#15. Apagar com retorno:
nota = aluno.pop("nota", "Chave não encontrada")

# %%
#16. Apagar tudo:
aluno.clear()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
usuario_filmes = {
    "Nome":[] , "Filmes":[]
}

print("=====MENU=====\n[1]Adicionar Filmes\n[2]Remover Filmes\n[3]Ver filmes de um Catálogo\n[4]Ver todos os Catálogos\n[0]SAIR")

while True:
 try:
  op = int(input("[Escolha uma das opções]: "))
  break
 except:
  print("!ESCOLHA UM OPÇÃO VÁLIDA!")

match op:
 
 case 1:
  caso_1 = input("Qual filme deseja adicionar: ") 
  usuario_filmes["Filmes"] = caso_1
  print("Filmes Adicionado ao Catálogo")

 case 2: 
  caso_2 = input

print(usuario_filmes)
